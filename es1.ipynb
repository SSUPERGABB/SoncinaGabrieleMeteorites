# %%
import json

with open("meteorites.json") as f:
    dati_meteoriti = json.load(f)

# %%
print("Tipo dell'oggetto:", type(dati_meteoriti))
print("Numero totale di meteoriti:", len(dati_meteoriti))

# %%
print(dati_meteoriti[0].keys())

# %%
for i in range(5):
    print("--- Meteorite: " + i + " ---")
    print(dati_meteoriti[i])
